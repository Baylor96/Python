# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_excel('/media/ljy/datadisk/U/Seismic_Data/Vp_vel_xfj.xls')

# %%
data
# Out:
#           x     y     z      vp  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0    114.40  23.6  0.20  6.4601         NaN         NaN         NaN
# 1    114.50  23.6  0.20  6.3809         NaN         NaN         NaN
# 2    114.55  23.6  0.20  6.3853         NaN         NaN         NaN
# 3    114.60  23.6  0.20  6.3748         NaN         NaN         NaN
# 4    114.63  23.6  0.20  6.3897         NaN         NaN         NaN
# ..      ...   ...   ...     ...         ...         ...         ...
# 643  114.63  24.0 -0.01  4.9200         NaN         NaN         NaN
# 644  114.66  24.0 -0.01  4.9200         NaN         NaN         NaN
# 645  114.70  24.0 -0.01  4.9200         NaN         NaN         NaN
# 646  114.80  24.0 -0.01  4.9200         NaN         NaN         NaN
# 647  115.00  24.0 -0.01  4.9489         NaN         NaN         NaN
#
#      Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 0        114.40       23.60        0.20          NaN          NaN
# ...

# %%
data_x = data.sort_values(by=['x','y','z'], ascending=[True, True, False])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-9764a2a1afdf> in <module>
# ----> 1 data_x = data.sort_values(by=['x','y','z'], ascending=[True, True, False], reverse=False)
#
# TypeError: sort_values() got an unexpected keyword argument 'reverse'

# %%
data_x
# Out:
#          x     y     z      vp  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0    114.4  23.6  0.20  6.4601         NaN         NaN         NaN
# 81   114.4  23.6  0.16  6.0703         NaN         NaN         NaN
# 162  114.4  23.6  0.13  5.9603         NaN         NaN         NaN
# 243  114.4  23.6  0.10  6.1465         NaN         NaN         NaN
# 324  114.4  23.6  0.07  6.0185         NaN         NaN         NaN
# ..     ...   ...   ...     ...         ...         ...         ...
# 323  115.0  24.0  0.10  6.3800         NaN         NaN         NaN
# 404  115.0  24.0  0.07  6.1065         NaN         NaN         NaN
# 485  115.0  24.0  0.03  5.3762         NaN         NaN         NaN
# 566  115.0  24.0  0.00  5.0775         NaN         NaN         NaN
# 647  115.0  24.0 -0.01  4.9489         NaN         NaN         NaN
#
#      Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 0         114.4        23.6         0.2          NaN          NaN
# ...

# %%
9*9*8

# %%
9*9*70

# %%
9*80*70

# %%
80*80*70

# %%
data_ds = data_x.loc[:,['vp']].values.flatten()
data_ds

# %%
data_dt = data_ds.tolist()

# %%
f = open('/media/b410/DATA/data/Seismic_data/xfj_vp_raw','wt')
f.writelines('%d\n' % 1)
f.writelines(str(len(data_ds)) + '\n')
for j in range(len(data_ds)):
    f.writelines(str(data_ds[j]) + '\n')
f.close()
